# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
triang_data = np.loadtxt('../data/results/N_coef_results.txt', skiprows=1)
gamma = np.loadtxt('../data/results/gamma_results.txt')
Z = np.loadtxt('../data/results/data_eval.txt')

# %%
Z.shape
# Out:
# (41, 61)

# %%
x = np.arange(0, 0.61, 0.01)
y = np.arange(0, 0.41, 0.01)

X, Y = np.meshgrid(x, y)

# %%
X.shape
# Out:
# (41, 61)

# %%
fig = plt.figure(figsize=(12, 7))
ax = plt.axes(projection='3d')
ax.plot_surface(X, Y, Z, rstride=1, cstride=1,
                cmap='viridis', edgecolor='none')
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0.5, 0, 'y')
